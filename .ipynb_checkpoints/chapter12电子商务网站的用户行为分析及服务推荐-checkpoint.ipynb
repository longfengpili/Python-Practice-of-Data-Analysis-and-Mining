# %%
# !git add .
# !git commit -m 'chapter12'
# !git push

# %% [markdown]
# # 数据探索

# %%
from sqlalchemy import create_engine

# 先自定义函数将表格写入数据库里，以备操作过程中有些数据要写入数据库
def savetosql(df,tablename):
    yconnect = create_engine('mysql+pymysql://longfengpili:mysql@123456@127.0.0.1:3306/chapter12?charset=utf8')  
    df.to_sql(tablename, yconnect, if_exists='append')

# %%
import pymysql
conn = pymysql.Connect(host = '127.0.0.1', port = 3306, user = 'longfengpili', passwd = 'mysql@123456', db = 'chapter12', charset="utf8")
data = pd.read_sql('select * from all_gzdata',conn,chunksize=1000)
counts = [i['fullURLId'].value_counts() for i in data] #逐块统计
counts = pd.concat(counts).groupby(level=0).sum()
counts = counts.reset_index()
counts = counts.rename(columns={'index':'fullURLId','fullURLId':'counts'})
counts['type'] = counts['fullURLId'].str.extract('(\d{3})')
counts_1 = counts.groupby('type')['counts'].sum().sort_values()
counts_2 = counts_1/counts_1.sum()
fig,axes = plt.subplots(1,1)
axes
a = axes.barh(counts_1.index,counts_1.values)
# b = axes[1].bar(counts_2.index,counts_2.values)
for i in range(len(a)):
    plt.text(a[i].get_x()+a[i].get_width(),a[i].get_y()+a[i].get_height()/2,'{},{:.2%}'.format(counts_1.values[i],counts_2.values[i]))
# Out:
# Text(1715,0.0,'1715,0.20%')
# Text(3957,1.0,'3957,0.47%')
# Text(17357,2.0,'17357,2.07%')
# Text(18430,3.0,'18430,2.20%')
# Text(182900,4.0,'182900,21.84%')
# Text(201426,5.0,'201426,24.05%')
# Text(411665,6.0,'411665,49.16%')

# %%
import pymysql
conn = pymysql.Connect(host = '127.0.0.1', port = 3306, user = 'longfengpili', passwd = 'mysql@123456', db = 'chapter12', charset="utf8")
data = pd.read_sql('select * from all_gzdata',conn,chunksize=1000)
counts = [i['fullURLId'].value_counts() for i in data] #逐块统计
counts = pd.concat(counts).groupby(level=0).sum()
counts = counts.reset_index()
counts = counts.rename(columns={'index':'fullURLId','fullURLId':'counts'})
counts['type'] = counts['fullURLId'].str.extract('(\d{3})')
counts['type_1'] = counts['fullURLId'].str.extract('(\d{6})')
counts_1 = counts[counts['type'] == '101'].groupby('type_1')['counts'].sum().sort_values()
counts_2 = counts_1/counts_1.sum()
fig,axes = plt.subplots(1,1)
axes
a = axes.barh(counts_1.index,counts_1.values)
# b = axes[1].bar(counts_2.index,counts_2.values)
for i in range(len(a)):
    plt.text(a[i].get_x()+a[i].get_width(),a[i].get_y()+a[i].get_height()/2,'{},{:.2%}'.format(counts_1.values[i],counts_2.values[i]))
# Out:
# Text(63,0.0,'63,0.02%')
# Text(107,1.0,'107,0.03%')
# Text(125,2.0,'125,0.03%')
# Text(147,3.0,'147,0.04%')
# Text(378,4.0,'378,0.09%')
# Text(854,5.0,'854,0.21%')
# Text(5603,6.0,'5603,1.36%')
# Text(7776,7.0,'7776,1.89%')
# Text(396612,8.0,'396612,96.34%')

# %%
import pymysql
conn = pymysql.Connect(host = '127.0.0.1', port = 3306, user = 'longfengpili', passwd = 'mysql@123456', db = 'chapter12', charset="utf8")
data = pd.read_sql('select * from all_gzdata',conn,chunksize=10000)

def count107(i):
    j = i[['fullURL']][i['fullURLId'].str.contains('107')].copy()
    j['type'] = 'error'
    j['type'][j['fullURL'].str.contains('info/.*?/')] = 'main'
    j['type'][j['fullURL'].str.contains('info/.*?.html')] = 'list'
    j['type'][j['fullURL'].str.contains('info/.*?/\d+_*\d+.html')] = 'note'
    
    return j
counts2 = [count107(i)['type'].value_counts() for i in data]
counts2_1 = pd.concat(counts2).groupby(level=0).sum().sort_values()
counts2_2 = counts2_1/counts2_1.sum()
fig,axes = plt.subplots(1,1)
axes
a = axes.barh(counts2_1.index,counts2_1.values)
# b = axes[1].bar(counts_2.index,counts_2.values)
for i in range(len(a)):
    plt.text(a[i].get_x()+a[i].get_width(),a[i].get_y()+a[i].get_height()/2,'{},{:.2%}'.format(counts2_1.values[i],counts2_2.values[i]))
# Out:
# Text(814,0.0,'814,0.45%')
# Text(17843,1.0,'17843,9.76%')
# Text(164243,2.0,'164243,89.80%')

# %%
import pymysql
conn = pymysql.Connect(host = '127.0.0.1', port = 3306, user = 'longfengpili', passwd = 'mysql@123456', db = 'chapter12', charset='utf8')
data = pd.read_sql('select * from all_gzdata',conn,chunksize=1000)
#-----* 3 *----- 统计带"?"问号网址类型统计
# 注意获取一次sql对象就需要重新访问一下数据库

def countquestion(i): #自定义统计函数
    j = i[['fullURLId']][i['fullURL'].str.contains('\?')].copy() #找出类别包含107的网址
    return j

counts3 = [countquestion(i)['fullURLId'].value_counts() for i in data]
counts3 = pd.concat(counts3).groupby(level=0).sum()
# 求各个类型的占比并保存数据
df1 =  pd.DataFrame(counts3)
df1['perc'] = df1['fullURLId']/df1['fullURLId'].sum()*100
df1.sort_values(by='fullURLId',ascending=False,inplace=True)
df1
# Out:
#          fullURLId       perc
# 1999001      64718  98.818176
# 301001         356   0.543578
# 107001         346   0.528309
# 101003          47   0.071764
# 102002          25   0.038173

# %%
#-----* 4 *----- 统计199类型中的具体类型占比
# conn = pymysql.Connect(host = '127.0.0.1', port = 3306, user = 'longfengpili', passwd = 'mysql@123456', db = 'chapter12', charset='utf8')
# data = pd.read_sql('select * from all_gzdata',conn,chunksize=1000)

def page199(i): #自定义统计函数
    j = i[['fullURL','pageTitle']][(i['fullURLId'].str.contains('199')) & (i['fullURL'].str.contains('\?'))]
    j['pageTitle'].fillna(u'空',inplace=True)
    j['type'] = u'其他' # 添加空列
    j['type'][j['pageTitle'].str.contains(u'法律快车-律师助手')]= u'法律快车-律师助手'
    j['type'][j['pageTitle'].str.contains(u'咨询发布成功')]= u'咨询发布成功'
    j['type'][j['pageTitle'].str.contains(u'免费发布法律咨询' )] = u'免费发布法律咨询'
    j['type'][j['pageTitle'].str.contains(u'法律快搜')] = u'快搜'
    j['type'][j['pageTitle'].str.contains(u'法律快车法律经验')] = u'法律快车法律经验'
    j['type'][j['pageTitle'].str.contains(u'法律快车法律咨询')] = u'法律快车法律咨询'
    j['type'][(j['pageTitle'].str.contains(u'_法律快车')) | (j['pageTitle'].str.contains(u'-法律快车'))] = u'法律快车'
    j['type'][j['pageTitle'].str.contains(u'空')] = u'空'
    
    return j
# 注意：获取一次sql对象就需要重新访问一下数据库
from sqlalchemy import create_engine
engine = create_engine('mysql+pymysql://longfengpili:mysql@123456@127.0.0.1:3306/chapter12?charset=utf8')
data = pd.read_sql('all_gzdata', engine, chunksize = 10000)# 分块读取数据库信息

counts4 = [page199(i) for i in data] # 逐块统计
counts4 = pd.concat(counts4)
d1 = counts4['type'].value_counts()
print(d1)
d2 = counts4[counts4['type']==u'其他']
# print(d2)
d2.to_sql(name='199elsePercentage',con=engine,if_exists='append',index=False)
# DataFrame(d2).to_sql(name='199elsePercentage',con=engine,if_exists='append',index=False)
# Out:
# c:\python36\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xD6\\xD0\\xB9\\xFA\\xB1\\xEA...' for column 'VARIABLE_VALUE' at row 480")
#   result = self._query(query)
# 法律快车-律师助手    49894
# 法律快车法律咨询      6421
# 咨询发布成功        5220
# 快搜            1943
# 法律快车           818
# 其他             359
# 法律快车法律经验        59
# 空                4
# Name: type, dtype: int64
# c:\python36\lib\site-packages\pandas\io\sql.py:1144: UserWarning: The provided table name '199elsePercentage' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   warnings.warn(msg, UserWarning)

# %%
d1_1 = DataFrame(d1)  #d1.to_frame()
d1_1['prec'] = d1_1['type']/d1_1['type'].sum()
d1_1.sort_values(by='type',ascending=False)
# Out:
#             type      prec
# 法律快车-律师助手  49894  0.770945
# 法律快车法律咨询    6421  0.099215
# 咨询发布成功      5220  0.080658
# 快搜          1943  0.030023
# 法律快车         818  0.012639
# 其他           359  0.005547
# 法律快车法律经验      59  0.000912
# 空              4  0.000062

# %%
#-----* 5 *----- 统计瞎逛用户中各个类型占比（没有具体的网页以.html后缀结尾）

def xiaguang(i): #自定义统计函数
    j = i[['fullURL','fullURLId','pageTitle']][(i['fullURL'].str.contains('\.html'))==False]
    return j

# 注意获取一次sql对象就需要重新访问一下数据库
from sqlalchemy import create_engine
engine = create_engine('mysql+pymysql://longfengpili:mysql@123456@127.0.0.1:3306/chapter12?charset=utf8')
data = pd.read_sql('all_gzdata', engine, chunksize = 10000)# 分块读取数据库信息

counts5 = [xiaguang(i) for i in data]
counts5 = pd.concat(counts5)

# 将瞎逛的值保存到数据库表中
counts5.to_sql(name='xiaguang',con=engine,if_exists='append',index=False)

xg1 = counts5['fullURLId'].value_counts()
xg1
# Out:
# c:\python36\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xD6\\xD0\\xB9\\xFA\\xB1\\xEA...' for column 'VARIABLE_VALUE' at row 480")
#   result = self._query(query)
# 1999001    117124
# 107001      17843
# 102002      12021
# 101001       5603
# 106001       3957
# 102001       2129
# 102003       1235
# 301001       1018
# 101009        854
# 102007        538
# 102008        404
# 101008        378
# 102004        361
# 102005        271
# 102009        214
# 102006        184
# 101004        125
# 101006        107
# 101005         63
# Name: fullURLId, dtype: int64

# %%
# 求各个部分的占比并保存数据
xg_ =  pd.DataFrame(xg1)
xg_.reset_index(inplace=True)
xg_.columns= ['index', 'num']
xg_['perc'] = xg_['num']/xg_['num'].sum()*100
xg_.sort_values(by='num',ascending=False,inplace=True)

xg_['type'] = xg_['index'].str.extract('(\d{3})') #提取前三个数字作为类别id    
xg_


xgs_ = xg_[['type', 'num']].groupby('type').sum() #按类别合并
xgs_.sort_values(by='num', ascending=False,inplace=True) #降序排列
xgs_['percentage'] = xgs_['num']/xgs_['num'].sum()*100
xgs_
# Out:
#       index     num       perc type
# 0   1999001  117124  71.230744  199
# 1    107001   17843  10.851492  107
# 2    102002   12021   7.310754  102
# 3    101001    5603   3.407550  101
# 4    106001    3957   2.406510  106
# 5    102001    2129   1.294784  102
# 6    102003    1235   0.751084  102
# 7    301001    1018   0.619112  301
# 8    101009     854   0.519373  101
# 9    102007     538   0.327193  102
# 10   102008     404   0.245699  102
# 11   101008     378   0.229886  101
# 12   102004     361   0.219548  102
# 13   102005     271   0.164813  102
# 14   102009     214   0.130147  102
# 15   102006     184   0.111902  102
# 16   101004     125   0.076021  101
# 17   101006     107   0.065074  101
# 18   101005      63   0.038314  101
#          num  percentage
# type
# 199   117124   71.230744
# 107    17843   10.851492
# 102    17357   10.555924
# 101     7130    4.336218
# 106     3957    2.406510
# 301     1018    0.619112

# %%
# 读取数据库数据
engine = create_engine('mysql+pymysql://longfengpili:mysql@123456@127.0.0.1:3306/chapter12?charset=utf8')
sql = pd.read_sql('all_gzdata', engine, chunksize = 10000)


#-----* 1 *-----统计点击次数

counts1 = [i['realIP'].value_counts() for i in sql] # 分块统计各个IP的出现次数
counts1 = pd.concat(counts1).groupby(level=0).sum() # 合并统计结果，level=0表示按照index分组

counts1.sort_values(ascending=False)
# Out:
# c:\python36\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xD6\\xD0\\xB9\\xFA\\xB1\\xEA...' for column 'VARIABLE_VALUE' at row 480")
#   result = self._query(query)
# 3812410744    42790
# 2609113527    41440
# 3875285307     3306
# 3791399227     2413
# 259451063      2000
# 225896631      1874
# 276228279      1858
# 818595448      1770
# 242673847      1682
# 2666105043     1455
# 2800322771     1413
# 3275680439     1353
# 2716436691     1332
# 1190924814     1305
# 1157370382     1147
# 1174147598     1089
# 4178061627     1053
# 3841730875     1050
# 518198490      1030
# 3549850737      978
# 1973622542      955
# 1383154801      936
# 1207702030      897
# 794953849       845
# 3063882359      838
# 3961223025      752
# 2955053173      708
# 851799153       670
# 4017821044      643
# 3684307470      621
#               ...
# 3277434748        1
# 3277348977        1
# 1773444307        1
# 1773494384        1
# 3277289486        1
# 3277288974        1
# 3277278064        1
# 1773559920        1
# 1773564892        1
# 1773565454        1
# 1773566222        1
# 1773606670        1
# 1773616698        1
# 3277274682        1
# 1773933070        1
# 3277267321        1
# 3277230862        1
# 1773683313        1
# 3277226359        1
# 3277222926        1
# 3277222414        1
# 1773825905        1
# 3277209146        1
# 1773857207        1
# 3277204027        1
# 1773887601        1
# 3277161079        1
# 1773896311        1
# 1773907827        1
# 4294917690        1
# Name: realIP, Length: 230149, dtype: int64

# %%
counts1_ = DataFrame(counts1)
counts1_[1]=1 # 添加1列全为1
a = counts1_.groupby('realIP').sum()#统计各个“不同点击次数”分别出现的次数# 也可以使用counts1_['realIP'].value_counts()功能
a.columns=[u'用户数']
a.index.name = u'点击次数'
a[u'用户百分比'] = a[u'用户数']/a[u'用户数'].sum()*100
a[u'记录百分比'] = a[u'用户数']*a.index/counts1_['realIP'].sum()*100
b1 = a.iloc[:7,:]
b2 = DataFrame(a.loc[8:,:].sum())
c = pd.concat([b1.T,b2],axis=1)
c.columns = list('1234567')+['>7']
c
# Out:
#                    1             2             3             4            5  \
# 用户数    132119.000000  44175.000000  17573.000000  10156.000000  5952.000000
# 用户百分比      57.405854     19.194087      7.635488      4.412793     2.586151
# 记录百分比      15.776345     10.549884      6.295182      4.850916     3.553645
#
#                  6            7            >7
# 用户数    4132.000000  2632.000000  13410.000000
# 用户百分比     1.795359     1.143607      5.826660
# 记录百分比     2.960416     2.200012     53.813601

# %%
# 转置表格，并将所有输出保留两位小数
d = c.T
format = lambda x: '%.2f' % x  # 也可以使用d.round(4)
d = d.applymap(format)
d
# Out:
#           用户数  用户百分比  记录百分比
# 1   132119.00  57.41  15.78
# 2    44175.00  19.19  10.55
# 3    17573.00   7.64   6.30
# 4    10156.00   4.41   4.85
# 5     5952.00   2.59   3.55
# 6     4132.00   1.80   2.96
# 7     2632.00   1.14   2.20
# >7   13410.00   5.83  53.81

# %%
# 分析浏览次数7次以上的数据
times = counts1_['realIP'].values
times
bins = [0,7,100,1000,50000]
cats = pd.cut(times,bins,right=True,labels=['0~7',"8~100","101~1000","1000以上"])
cats
e = cats.value_counts()
e = DataFrame(e, columns =[u'用户数'])
e.index.name = u'点击次数'
e
# Out:
# array([2, 1, 1, ..., 3, 2, 1], dtype=int64)
# [0~7, 0~7, 0~7, 0~7, 0~7, ..., 0~7, 0~7, 0~7, 0~7, 0~7]
# Length: 230149
# Categories (4, object): [0~7 < 8~100 < 101~1000 < 1000以上]
#              用户数
# 点击次数
# 0~7       216739
# 8~100      12952
# 101~1000     439
# 1000以上        19

# %%
# 获取浏览一次的所有数据
f = counts1_[counts1_['realIP']==1]
del f[1]
f.columns = [u'点击次数']
f.index.name = 'realIP'
# f[:5]
# 读取数据库数据
engine = create_engine('mysql+pymysql://longfengpili:mysql@123456@127.0.0.1:3306/chapter12?charset=utf8')
sql = pd.read_sql('all_gzdata', engine, chunksize = 10000)

g = [pd.merge(f,i[['fullURLId','fullURL','realIP']],right_on = 'realIP',left_index=True,how ='right') for i in sql]
g = pd.concat(g)
h = g.dropna()
h
# g = [i[['fullURLId','fullURL','realIP']] for i in sql]
# g = pd.concat(g)
# h = pd.merge(f,g,right_on = 'realIP',left_index=True,how ='left')
# h
# Out:
# c:\python36\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\
# 7362   1.0    107001  http://www.lawtime.cn/info/hunyin/jhsy/daiyun/...
# 7374   1.0    101003   http://www.lawtime.cn/ask/question_10658237.html
# 7376   1.0    107001  http://www.lawtime.cn/info/hunyin/lhlawlhxy/20...
# 7377   1.0    101003     http://www.lawtime.cn/ask/question_740870.html
# 7380   1.0    101003    http://www.lawtime.cn/ask/question_5236139.html
# 7381   1.0    101003    http://www.lawtime.cn/ask/question_3666283.html
# 7387   1.0    101003    http://www.lawtime.cn/ask/question_2107922.html
# 7412   1.0    101003    http://www.lawtime.cn/ask/question_5670322.html
# 7413   1.0    101003    http://www.lawtime.cn/ask/question_1172879.html
# 7416   1.0    101003    http://www.lawtime.cn/ask/question_6272135.html
# 7421   1.0    101003    http://www.lawtime.cn/ask/question_5869007.html
# 7422   1.0    101003    http://www.lawtime.cn/ask/question_9772651.html
# 7426   1.0    101003    http://www.lawtime.cn/ask/question_6905917.html
# 7436   1.0   1999001              http://www.lawtime.cn/faguizt/15.html
# 7441   1.0    101003   http://www.lawtime.cn/ask/question_10030566.html
#
#           realIP
# 1      973705742
# 2     3104681075
# 15    4173218417
# 16    3552806875
# 18    3017251342
# 20     114516081
# 21    3802099569
# 23    1561948430
# 25    4178023182
# 31    3932407668
# 34    3834551054
# 37    3068608881
# 38    3673002254
# 41    1044414839
# 46    3614602510
# 49    2577948784
# 55    1738125180
# 60    1524907578
# 61    1834403804
# 66    3069271664
# 67    3864019057
# 69     760644215
# 72     998118670
# 75    1974105870
# 82    2173124977
# 83    2565177102
# 87     369325326
# 91    2900974192
# 93    1386881911
# 97    1372013681
# ...          ...
# 7290  2607624119
# 7293  4071035406
# 7294  1553379196
# 7295  1449560283
# 7307   119315214
# 7311  2310174990
# 7312   412685070
# 7316   859930999
# 7320   751049742
# 7330  1628192314
# 7331  1937609742
# 7334  3345690551
# 7340  2610323569
# 7346  1295910327
# 7352  4022223473
# 7362  3458366734
# 7374  4041982175
# 7376  4267065457
# 7377  2708542836
# 7380   114531086
# 7381  1337214065
# 7387   128752142
# 7412  2698934129
# 7413   823268724
# 7416  2420800014
# 7421   761362190
# 7422  2339226744
# 7426  3792135025
# 7436   263980471
# 7441  3399783182
#
# [132119 rows x 4 columns]

# %%
# 浏览一次的用户的网页类型ID分析
i = h['fullURLId'].value_counts()
i = DataFrame(i)
i.rename(columns={'fullURLId':u'个数'},inplace=True)
i.index.name = u'网页类型ID'
i[u'百分比'] = i[u'个数']/i[u'个数'].sum()*100
i
# Out:
#              个数        百分比
# 网页类型ID
# 101003   102560  77.626988
# 107001    19443  14.716279
# 1999001    9381   7.100417
# 301001      515   0.389800
# 102001       70   0.052983
# 103003       45   0.034060
# 101002       33   0.024977
# 101001       28   0.021193
# 102002       13   0.009840
# 106001       13   0.009840
# 101009        4   0.003028
# 101004        3   0.002271
# 101007        3   0.002271
# 101008        2   0.001514
# 102003        2   0.001514
# 102006        1   0.000757
# 102004        1   0.000757
# 101005        1   0.000757
# 101006        1   0.000757

# %%
j = i[i[u'个数']>100]
j.loc[u'其他',u'个数'] = i[i[u'个数']<=100][u'个数'].sum()
j.loc[u'其他',u'百分比'] = 100-i[i[u'个数']>100][u'百分比'].sum()
j# 浏览一次的用户中浏览的网页类型ID
# Out:
# c:\python36\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                个数        百分比
# 网页类型ID
# 101003   102560.0  77.626988
# 107001    19443.0  14.716279
# 1999001    9381.0   7.100417
# 301001      515.0   0.389800
# 其他          220.0   0.166517

# %%
#　点击1次用户浏览网页统计(点击数大于100次的)
k = DataFrame(h['fullURL'].value_counts())
k.index.name = u'网址'
k.columns = [u'点击数']
m = k[k[u'点击数'] > 100]
m.loc[u'其他',u'点击数'] = k[k[u'点击数']<=100][u'点击数'].sum()
m[u'百分比'] = m[u'点击数']/k[u'点击数'].sum()
m
# Out:
# c:\python36\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                                                          点击数       百分比
# 网址
# http://www.lawtime.cn/info/shuifa/slb/201211197...    1013.0  0.007667
# http://www.lawtime.cn/info/hunyin/lhlawlhxy/201...     501.0  0.003792
# http://www.lawtime.cn/ask/question_925675.html         423.0  0.003202
# http://www.lawtime.cn/info/shuifa/slb/201211197...     367.0  0.002778
# http://www.lawtime.cn/ask/exp/13655.html               301.0  0.002278
# http://www.lawtime.cn/ask/exp/8495.html                241.0  0.001824
# http://www.lawtime.cn/ask/exp/13445.html               199.0  0.001506
# http://www.lawtime.cn/guangzhou                        177.0  0.001340
# http://www.lawtime.cn/ask/exp/17357.html               171.0  0.001294
# http://www.lawtime.cn/citylist.php                     117.0  0.000886
# http://www.lawtime.cn/ask/exp/13943.html               117.0  0.000886
# http://www.lawtime.cn/info/shuifa/grsds/2014103...     111.0  0.000840
# http://www.lawtime.cn/ask/question_7148707.html        104.0  0.000787
# 其他                                                  128277.0  0.970920

# %%
# 读取数据库数据
engine = create_engine('mysql+pymysql://longfengpili:mysql@123456@127.0.0.1:3306/chapter12?charset=utf8')
sql = pd.read_sql('all_gzdata', engine, chunksize = 10000)

def clickfreq(i): #自定义统计函数
    j = i[['fullURL','fullURLId','realIP']][i['fullURL'].str.contains('\.html')]
    return j

counts1 = [clickfreq(i) for i in sql] # 分块统计各个IP的出现次数
counts1 = pd.concat(counts1)

counts1_ = counts1['fullURL'].value_counts()
counts1_ = DataFrame(counts1_)
# Out:
# c:\python36\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xD6\\xD0\\xB9\\xFA\\xB1\\xEA...' for column 'VARIABLE_VALUE' at row 480")
#   result = self._query(query)

# %%
counts1_.columns = [u'点击次数']
counts1_.index.name = u'网址'
a = counts1_.sort_values(u'点击次数',ascending=False).iloc[:20,:]
a
# Out:
#                                                     点击次数
# 网址
# http://www.lawtime.cn/faguizt/23.html               6503
# http://www.lawtime.cn/info/hunyin/lhlawlhxy/201...  4938
# http://www.lawtime.cn/faguizt/9.html                4562
# http://www.lawtime.cn/info/shuifa/slb/201211197...  4495
# http://www.lawtime.cn/faguizt/11.html               3976
# http://www.lawtime.cn/info/hunyin/lhlawlhxy/201...  3305
# http://www.lawtime.cn/faguizt/43.html               3251
# http://www.lawtime.cn/faguizt/15.html               2718
# http://www.lawtime.cn/faguizt/117.html              2670
# http://www.lawtime.cn/faguizt/41.html               2455
# http://www.lawtime.cn/info/shuifa/slb/201211197...  2161
# http://www.lawtime.cn/faguizt/131.html              1561
# http://www.lawtime.cn/ask/browse_a1401.html         1305
# http://www.lawtime.cn/faguizt/21.html               1210
# http://www.lawtime.cn/ask/exp/13655.html            1060
# http://www.lawtime.cn/faguizt/39.html               1059
# http://www.lawtime.cn/faguizt/79.html                916
# http://www.lawtime.cn/ask/question_925675.html       879
# http://www.lawtime.cn/faguizt/7.html                 845
# http://www.lawtime.cn/ask/exp/8495.html              726

# %%
#-----* 2 *-----获取网页点击排名数筛选出点击次数>50的有html结尾的网址
b = counts1_.reset_index()
c = b[b[u'点击次数']>50][b[u'网址'].str.contains('html$')]
c.set_index(u'网址',inplace=True)
c.sort_index(inplace = True)
c[:5]
# Out:
# c:\python36\lib\site-packages\ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
#                                                点击次数
# 网址
# http://law.lawtime.cn/d470073475167.html        140
# http://law.lawtime.cn/d470073475167_1_p2.html    70
# http://law.lawtime.cn/d470073475167_1_p3.html    78
# http://law.lawtime.cn/d470073475167_1_p4.html    55
# http://law.lawtime.cn/d470073475167_1_p5.html    55

# %%
#-----* 3 *-----翻页网页统计，对浏览网页翻页的情况进行统计
# 获取网址中以http://与.html中间的主体部分,即去掉翻页的内容，即去掉尾部"_d"
import re
pattern = re.compile('http://(.*\d+?)_\w+_\w+\.html$|http://(.*\d+?)_\w+\.html$|http://(.*\w+?).html$',re.S)
c['websitemain'] = np.nan
for i in range(len(c)):
    items = re.findall(pattern, c.index[i])
    if len(items)== 0:
        temp = np.nan
    else:
        for j in items[0]:
            if j !='':
                temp = j
    c.iloc[i,1] = temp
c
# Out:
#                                                     点击次数  \
# 网址
# http://law.lawtime.cn/d470073475167.html             140
# http://law.lawtime.cn/d470073475167_1_p2.html         70
# http://law.lawtime.cn/d470073475167_1_p3.html         78
# http://law.lawtime.cn/d470073475167_1_p4.html         55
# http://law.lawtime.cn/d470073475167_1_p5.html         55
# http://law.lawtime.cn/d673308678402.html              54
# http://law.lawtime.cn/d699306704400.html              67
# http://law.lawtime.cn/d704908710002.html              87
# http://law.lawtime.cn/d705226710320.html              83
# http://law.lawtime.cn/d705226710320_2_p1.html         56
# http://law.lawtime.cn/dffg.html                       86
# http://law.lawtime.cn/gjfg.html                       84
# http://law.lawtime.cn/sfjs.html                       52
# http://www.lawtime.cn/ask/browse.html                699
# http://www.lawtime.cn/ask/browse_a14.html            150
# http://www.lawtime.cn/ask/browse_a1401.html         1305
# http://www.lawtime.cn/ask/browse_a1402.html          134
# http://www.lawtime.cn/ask/browse_p2.html              71
# http://www.lawtime.cn/ask/browse_s2.html              59
# http://www.lawtime.cn/ask/browse_s4.html             136
# http://www.lawtime.cn/ask/browse_s57.html             68
# http://www.lawtime.cn/ask/browse_s9.html             121
# http://www.lawtime.cn/ask/browse_t2.html              96
# http://www.lawtime.cn/ask/browse_t3.html              58
# http://www.lawtime.cn/ask/exp/10573.html              61
# http://www.lawtime.cn/info/minshi/fagui/2013051...      8    2  NaN
# http://www.lawtime.cn/info/minshi/fagui/2013051...      8    2  NaN
# http://www.lawtime.cn/info/shengchan/aqscfg/201...      5    8  NaN
# http://www.lawtime.cn/info/shengchan/aqscfg/201...      5    8  NaN
# http://www.lawtime.cn/info/shengchan/aqscfg/201...      5    8  NaN
# http://www.lawtime.cn/info/shengchan/aqscfg/201...      5    8  NaN
# http://www.lawtime.cn/info/shengchan/aqscfg/201...      5    8  NaN
# http://www.lawtime.cn/info/shuifa/grsds/2014011...      2   45  NaN
# http://www.lawtime.cn/info/shuifa/grsds/2014011...      2   45  NaN
# http://www.lawtime.cn/info/shuifa/grsds/2014012...      2   42  NaN
# http://www.lawtime.cn/info/shuifa/grsds/2014012...      2   42  NaN
# http://www.lawtime.cn/info/shuifa/grsds/2014021...      2   36  NaN
# http://www.lawtime.cn/info/shuifa/grsds/2014021...      2   36  NaN
# http://www.lawtime.cn/info/shuifa/grsds/2014021...      2   59  NaN
# http://www.lawtime.cn/info/shuifa/grsds/2014021...      2   59  NaN
# http://www.lawtime.cn/info/shuifa/grsds/2014022...      2   55  NaN
# http://www.lawtime.cn/info/shuifa/grsds/2014022...      2   55  NaN
# http://www.lawtime.cn/info/shuifa/grsds/2014103...      2   51  NaN
# http://www.lawtime.cn/info/shuifa/grsds/2014103...      2   51  NaN
# http://www.lawtime.cn/info/shuifa/slb/201211197...      2   50  NaN
# http://www.lawtime.cn/info/shuifa/slb/201211197...      2   50  NaN
# http://www.lawtime.cn/info/shuifa/ssfl/20140122...      5    5  NaN
# http://www.lawtime.cn/info/shuifa/ssfl/20140122...      5    5  NaN
# http://www.lawtime.cn/info/shuifa/ssfl/20140122...      5    5  NaN
# http://www.lawtime.cn/info/shuifa/ssfl/20140122...      5    5  NaN
# http://www.lawtime.cn/info/shuifa/ssfl/20140122...      5    5  NaN
# http://www.lawtime.cn/info/xiaofeizhe/law/quany...      2   44  NaN
# http://www.lawtime.cn/info/xiaofeizhe/law/quany...      2   44  NaN
# http://www.lawtime.cn/info/xingfa/xfsjliangxing...      2   49  NaN
# http://www.lawtime.cn/info/xingfa/xfsjliangxing...      2   49  NaN
#
# [176 rows x 5 columns]

# %%
# 统计翻子页的点击率与上一页网页点击率的比重（注意：用此处这个方法对网页翻页后序号有10页及以上的合适
def getper(x):
    x.sort_index(inplace=True) #必须先排序将网页
#     print x
    for i in range(len(x)-1):
        x.iloc[i+1,-1] = x.iloc[i+1,0]/x.iloc[i,0]
    return x    
        

result = DataFrame([]) # 用一个空表格记录值
for i in range(1,f['num'].max()+1):#count36['num'].max()+1
    k= getper(f[f['num'] == i])
    result = pd.concat([result,k])# 每次进行一次操作时
result.sort_index()
# Out:
# c:\python36\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# www.lawtime.cn/info/laodong/ldzyjqdy/2014110433...    0.00%   0.00%
# www.lawtime.cn/info/laodong/ldzyjygl/2014031214...    0.00%   0.00%
# www.lawtime.cn/info/laodong/ldzyjygl/2014031214...    0.00%   0.00%
# www.lawtime.cn/info/laodong/zuidigongzibiaozhun...    0.00%   0.00%
# www.lawtime.cn/info/minfa/minfafagui/2010060947918  104.55%  89.86%
# www.lawtime.cn/info/minshi/fagui/2013051382463       55.56%   0.00%
# www.lawtime.cn/info/shengchan/aqscfg/2014091233...    0.00%   0.00%
# www.lawtime.cn/info/shuifa/grsds/201401162877978      0.00%   0.00%
# www.lawtime.cn/info/shuifa/grsds/201401242878968      0.00%   0.00%
# www.lawtime.cn/info/shuifa/grsds/201402172880722      0.00%   0.00%
# www.lawtime.cn/info/shuifa/grsds/201402182880758      0.00%   0.00%
# www.lawtime.cn/info/shuifa/grsds/201402252881502      0.00%   0.00%
# www.lawtime.cn/info/shuifa/grsds/201410313308870      0.00%   0.00%
# www.lawtime.cn/info/shuifa/slb/2012111978933          0.00%   0.00%
# www.lawtime.cn/info/shuifa/ssfl/201401222878484       0.00%   0.00%
# www.lawtime.cn/info/xiaofeizhe/law/quanyifagui/...    0.00%   0.00%
# www.lawtime.cn/info/xingfa/xfsjliangxing/201408...    0.00%   0.00%

# %% [markdown]
# # 数据预处理
# ## 数据清洗

# %%
#-----* 1 *-----查看各个需要删除的规则包含的信息

# 删除规则1：统计中间类型网页（带midques_关键字）
# 读取数据库数据
engine = create_engine('mysql+pymysql://longfengpili:mysql@123456@127.0.0.1:3306/chapter12?charset=utf8')
sql = pd.read_sql('all_gzdata', engine, chunksize = 10000)

def countmidques(i): 
    j = i[['fullURL','fullURLId','realIP']].copy()
    j['type'] = u'非中间类型网页'
    j['type'][j['fullURL'].str.contains('midques_')]= u'中间类型网页'
    return j['type'].value_counts()
counts1 = [countmidques(i) for i in sql]
counts1 = pd.concat(counts1).groupby(level=0).sum()
counts1
# Out:
# F:\ProgramData\Anaconda3\envs\normal\lib\site-packages\pymysql\cursors.py:166: Warning: (1366, "Incorrect string value: '\\xD6\\xD0\\xB9\\xFA\\xB1\\xEA...' for column 'VARIABLE_VALUE' at row 481")
#   result = self._query(query)
# F:\ProgramData\Anaconda3\envs\normal\lib\site-packages\pymysql\cursors.py:166: Warning: (1287, "'@@tx_isolation' is deprecated and will be removed in a future release. Please use '@@transaction_isolation' instead")
#   result = self._query(query)
# F:\ProgramData\Anaconda3\envs\normal\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# 中间类型网页       2036
# 非中间类型网页    835414
# Name: type, dtype: int64

# %%
# 删除规则2：主网址去掉无.html点击行为的用户记录
# 读取数据库数据
engine = create_engine('mysql+pymysql://longfengpili:mysql@123456@127.0.0.1:3306/chapter12?charset=utf8')
sql = pd.read_sql('all_gzdata', engine, chunksize = 10000)

def countnohtml(i):
    j = i[['fullURL','pageTitle','fullURLId']].copy()
    j['type'] = u'有html页面'
    j['type'][j['fullURL'].str.contains('\.html')==False] = u'无.html点击行为的用户记录'
    
    return j['type'].value_counts()
counts2 = [countnohtml(i) for i in sql]
counts2 = pd.concat(counts2).groupby(level=0).sum()
counts2
# Out:
# F:\ProgramData\Anaconda3\envs\normal\lib\site-packages\pymysql\cursors.py:166: Warning: (1366, "Incorrect string value: '\\xD6\\xD0\\xB9\\xFA\\xB1\\xEA...' for column 'VARIABLE_VALUE' at row 481")
#   result = self._query(query)
# F:\ProgramData\Anaconda3\envs\normal\lib\site-packages\pymysql\cursors.py:166: Warning: (1287, "'@@tx_isolation' is deprecated and will be removed in a future release. Please use '@@transaction_isolation' instead")
#   result = self._query(query)
# 无.html点击行为的用户记录    164429
# 有html页面            673021
# Name: type, dtype: int64

# %%
# 删除规则3：主网址是律师的浏览信息网页（快车-律师助手）、咨询发布成功、快搜免费发布法律
# 读取数据库数据
# *备注：此规则中要删除的记录的网址均不含有.html，所以，规则三需要过滤的信息包含了规则2中需要过滤的
engine = create_engine('mysql+pymysql://longfengpili:mysql@123456@127.0.0.1:3306/chapter12?charset=utf8')
sql = pd.read_sql('all_gzdata', engine, chunksize = 10000)

def countothers(i): 
    j = i[['fullURL','pageTitle','fullURLId']].copy()
    j['type'] = u'其他'   
    j['pageTitle'].fillna(u'空',inplace=True)
    j['type'][j['pageTitle'].str.contains(u'快车-律师助手')]= u'快车-律师助手'
    j['type'][j['pageTitle'].str.contains(u'咨询发布成功')]= u'咨询发布成功'
    j['type'][(j['pageTitle'].str.contains(u'免费发布法律咨询')) | (j['pageTitle'].str.contains(u'法律快搜'))] = u'快搜免费发布法律咨询'
    
    return j['type'].value_counts()
counts3 = [countothers(i) for i in sql]
counts3 = pd.concat(counts3).groupby(level=0).sum()
counts3
# Out:
# F:\ProgramData\Anaconda3\envs\normal\lib\site-packages\pymysql\cursors.py:166: Warning: (1366, "Incorrect string value: '\\xD6\\xD0\\xB9\\xFA\\xB1\\xEA...' for column 'VARIABLE_VALUE' at row 481")
#   result = self._query(query)
# F:\ProgramData\Anaconda3\envs\normal\lib\site-packages\pymysql\cursors.py:166: Warning: (1287, "'@@tx_isolation' is deprecated and will be removed in a future release. Please use '@@transaction_isolation' instead")
#   result = self._query(query)
# 其他            767758
# 咨询发布成功          5220
# 快搜免费发布法律咨询     11604
# 快车-律师助手        52868
# Name: type, dtype: int64

# %%
# 删除规则4: 去掉网址中问号后面的部分，截取问号前面的部分;去掉主网址不包含关键字
engine = create_engine('mysql+pymysql://longfengpili:mysql@123456@127.0.0.1:3306/chapter12?charset=utf8')
sql = pd.read_sql('all_gzdata', engine, chunksize = 10000)

def deletquesafter(i):
    j = i[['fullURL']].copy()
    j['fullURL'] = j['fullURL'].str.replace('\?.*','')
    j['type'] = u'主网址不包含关键字'
    j['type'][j['fullURL'].str.contains('lawtime')] = u'主网址包含关键字'
    return j

counts4 = [deletquesafter(i) for i in sql]
counts4 = pd.concat(counts4)
print(len(counts4))
counts4['type'].value_counts()
# Out:
# F:\ProgramData\Anaconda3\envs\normal\lib\site-packages\pymysql\cursors.py:166: Warning: (1366, "Incorrect string value: '\\xD6\\xD0\\xB9\\xFA\\xB1\\xEA...' for column 'VARIABLE_VALUE' at row 481")
#   result = self._query(query)
# F:\ProgramData\Anaconda3\envs\normal\lib\site-packages\pymysql\cursors.py:166: Warning: (1287, "'@@tx_isolation' is deprecated and will be removed in a future release. Please use '@@transaction_isolation' instead")
#   result = self._query(query)
# 837450
# 主网址包含关键字     837349
# 主网址不包含关键字       101
# Name: type, dtype: int64

# %%
# 删除规则5: 重复数据去除
# 读取数据库数据
engine = create_engine('mysql+pymysql://longfengpili:mysql@123456@127.0.0.1:3306/chapter12?charset=utf8')
sql = pd.read_sql('all_gzdata', engine, chunksize = 10000)

def countduplicate(i): 
    j = i[['fullURL','timestamp_format','realIP']].copy()
    return j

counts5 = [countduplicate(i) for i in sql]
counts5 = pd.concat(counts5)

print(len(counts5[counts5.duplicated()==True]))
print(len(counts5.drop_duplicates()))
a = counts5.drop_duplicates()
# Out:
# F:\ProgramData\Anaconda3\envs\normal\lib\site-packages\pymysql\cursors.py:166: Warning: (1366, "Incorrect string value: '\\xD6\\xD0\\xB9\\xFA\\xB1\\xEA...' for column 'VARIABLE_VALUE' at row 481")
#   result = self._query(query)
# F:\ProgramData\Anaconda3\envs\normal\lib\site-packages\pymysql\cursors.py:166: Warning: (1287, "'@@tx_isolation' is deprecated and will be removed in a future release. Please use '@@transaction_isolation' instead")
#   result = self._query(query)
# 35479
# 801971

# %%
#-----* 2 *-----Python访问数据库进行清洗操作
# 第一步，完成删除规则1，2，4

# 对网址的操作 （只要.html结尾的 & 截取问号左边的值 & 只要包含主网址（lawtime)的&网址中间没有midques_的
# 读取数据库数据
engine = create_engine('mysql+pymysql://longfengpili:mysql@123456@127.0.0.1:3306/chapter12?charset=utf8')
sql = pd.read_sql('all_gzdata', engine, chunksize = 10000)

for i in sql:
    d = i[['realIP', 'fullURL','pageTitle','userID','timestamp_format']].copy() # 只要网址列
    d['fullURL'] = d['fullURL'].str.replace('\?.*','') # 替换掉网址中问号后面的部分   
    d = d[(d['fullURL'].str.contains('\.html')) & (d['fullURL'].str.contains('lawtime')) & (d['fullURL'].str.contains('midques_') == False)] # 只要含有.html的网址
    # 保存到数据库中
    d.to_sql('cleaned_one', engine, index = False, if_exists = 'append')
# Out:
# F:\ProgramData\Anaconda3\envs\normal\lib\site-packages\pymysql\cursors.py:166: Warning: (1366, "Incorrect string value: '\\xD6\\xD0\\xB9\\xFA\\xB1\\xEA...' for column 'VARIABLE_VALUE' at row 481")
#   result = self._query(query)
# F:\ProgramData\Anaconda3\envs\normal\lib\site-packages\pymysql\cursors.py:166: Warning: (1287, "'@@tx_isolation' is deprecated and will be removed in a future release. Please use '@@transaction_isolation' instead")
#   result = self._query(query)

# %%
# 第二步，完成删除规则3

# 对网页标题的操作 （删除 快车-律师助手 & 免费发布法律咨询 & 咨询发布成功 & 法律快搜）
# 读取数据库数据（基于操作1之后）
engine = create_engine('mysql+pymysql://longfengpili:mysql@123456@127.0.0.1:3306/chapter12?charset=utf8')
sql = pd.read_sql('cleaned_one', engine, chunksize = 10000)

# 对网址的操作 （只要.html结尾的&只要包含主网址（lawtime)的&网址中间没有midques_的
for i in sql:
    d = i[['realIP','fullURL','pageTitle','userID','timestamp_format']].copy()# 只要网址列
    d['pageTitle'].fillna(u'空',inplace=True)
    d = d[(d['pageTitle'].str.contains(u'快车-律师助手') == False) & (d['pageTitle'].str.contains(u'咨询发布成功') == False) & \
          (d['pageTitle'].str.contains(u'免费发布法律咨询') == False) & (d['pageTitle'].str.contains(u'法律快搜') == False)\
         ].copy()
    # 保存到数据库中
    d.to_sql('cleaned_two', engine, index = False, if_exists = 'append')
    
##### 注意：最后发现，对于网页标题需要进行的删除的记录的网址中，均没有.html，因此，操作2可以不必做，操作1已完成工作
# Out:
# F:\ProgramData\Anaconda3\envs\normal\lib\site-packages\pymysql\cursors.py:166: Warning: (1366, "Incorrect string value: '\\xD6\\xD0\\xB9\\xFA\\xB1\\xEA...' for column 'VARIABLE_VALUE' at row 481")
#   result = self._query(query)
# F:\ProgramData\Anaconda3\envs\normal\lib\site-packages\pymysql\cursors.py:166: Warning: (1287, "'@@tx_isolation' is deprecated and will be removed in a future release. Please use '@@transaction_isolation' instead")
#   result = self._query(query)

# %%
# 第三步，完成删除规则5

# 删除重复记录
# 读取数据库数据（基于第二步之后）
engine = create_engine('mysql+pymysql://longfengpili:mysql@123456@127.0.0.1:3306/chapter12?charset=utf8')
sql = pd.read_sql('cleaned_two', engine, chunksize = 10000)

def dropduplicate(i): 
    j = i[['realIP','fullURL','pageTitle','userID','timestamp_format']].copy()
    return j

count6 = [dropduplicate(i) for i in sql]
count6 = pd.concat(count6)
print(len(count6))
count7 = count6.drop_duplicates(['fullURL','userID','timestamp_format'])
print(len(count7))
savetosql(count7, 'cleaned_three')
# Out:
# F:\ProgramData\Anaconda3\envs\normal\lib\site-packages\pymysql\cursors.py:166: Warning: (1366, "Incorrect string value: '\\xD6\\xD0\\xB9\\xFA\\xB1\\xEA...' for column 'VARIABLE_VALUE' at row 481")
#   result = self._query(query)
# F:\ProgramData\Anaconda3\envs\normal\lib\site-packages\pymysql\cursors.py:166: Warning: (1287, "'@@tx_isolation' is deprecated and will be removed in a future release. Please use '@@transaction_isolation' instead")
#   result = self._query(query)
# 670965
# 647300

# %%
#-----* 3 *----- 查看进行删除操作后的表中的总记录数
# 查看all_gzdata表中的记录数
engine = create_engine('mysql+pymysql://longfengpili:mysql@123456@127.0.0.1:3306/chapter12?charset=utf8')
sql = pd.read_sql('all_gzdata', engine, chunksize = 10000)
lens = 0
for i in sql:
    temp = len(i)
    lens = temp + lens
print(lens)  # 837450

# 查看cleaned_one表中的记录数
engine = create_engine('mysql+pymysql://longfengpili:mysql@123456@127.0.0.1:3306/chapter12?charset=utf8')
sql1 = pd.read_sql('cleaned_one', engine, chunksize = 10000)
lens1 = 0
for i in sql1:
    temp = len(i)
    lens1 = temp + lens1
print(lens1) # 670965

# 查看cleaned_two表中的记录数
engine = create_engine('mysql+pymysql://longfengpili:mysql@123456@127.0.0.1:3306/chapter12?charset=utf8')
sql2 = pd.read_sql('cleaned_two', engine, chunksize = 10000)
lens2 = 0
for i in sql2:
    temp = len(i)
    lens2 = temp + lens2
print(lens2) # 670965

# 查看cleaned_three表中的记录数
engine = create_engine('mysql+pymysql://longfengpili:mysql@123456@127.0.0.1:3306/chapter12?charset=utf8')
sql3 = pd.read_sql('cleaned_three', engine, chunksize = 10000)
lens3 = 0
for i in sql3:
    temp = len(i)
    lens3 = temp + lens3
print(lens3) # 647300
# Out:
# F:\ProgramData\Anaconda3\envs\normal\lib\site-packages\pymysql\cursors.py:166: Warning: (1366, "Incorrect string value: '\\xD6\\xD0\\xB9\\xFA\\xB1\\xEA...' for column 'VARIABLE_VALUE' at row 481")
#   result = self._query(query)
# F:\ProgramData\Anaconda3\envs\normal\lib\site-packages\pymysql\cursors.py:166: Warning: (1287, "'@@tx_isolation' is deprecated and will be removed in a future release. Please use '@@transaction_isolation' instead")
#   result = self._query(query)
# 837450
# 670965
# 670965
# 647300

# %%
#-----* 1 *-----识别翻页的网址并且删除重复（用户ID和处理后的网址相同）的记录

# 读取数据库数据
engine = create_engine('mysql+pymysql://longfengpili:mysql@123456@127.0.0.1:3306/chapter12?charset=utf8')
sql = pd.read_sql('cleaned_three', engine, chunksize = 10000)

l0 = 0
l1 = 0
l2 = 0
for i in sql:
    d = i.copy()
    # 获取所有记录的个数
    temp0 = len(d)
    l0 = l0 + temp0
    
    # 获取类似于http://www.lawtime.cn***/2007020619634_2.html格式的记录的个数
    # 匹配1 易知，匹配1一定包含匹配2
    x1 = d[d['fullURL'].str.contains('_\d{0,2}.html')]
    temp1 = len(x1)
    l1 = l1 + temp1    

    # 匹配2
    # 获取类似于http://www.lawtime.cn***/29_1_p3.html格式的记录的个数
    x2 = d[d['fullURL'].str.contains('_\d{0,2}_\w{0,2}.html')]
    temp2 = len(x2)
    l2 = l2 + temp2
    
    x1.to_sql('l1', engine, index=False, if_exists = 'append') # 保存
    x2.to_sql('l2', engine, index=False, if_exists = 'append') # 保存

print(l0,l1,l2)
# Out:
# F:\ProgramData\Anaconda3\envs\normal\lib\site-packages\pymysql\cursors.py:166: Warning: (1366, "Incorrect string value: '\\xD6\\xD0\\xB9\\xFA\\xB1\\xEA...' for column 'VARIABLE_VALUE' at row 481")
#   result = self._query(query)
# F:\ProgramData\Anaconda3\envs\normal\lib\site-packages\pymysql\cursors.py:166: Warning: (1287, "'@@tx_isolation' is deprecated and will be removed in a future release. Please use '@@transaction_isolation' instead")
#   result = self._query(query)
# 647300 55455 9260

# %%
# 注意：在内部循环中，容易删除不完整，所以需要进行全部读取二次筛选删除
# 【初步筛选】
# 读取数据库数据
engine = create_engine('mysql+pymysql://longfengpili:mysql@123456@127.0.0.1:3306/chapter12?charset=utf8')
sql = pd.read_sql('cleaned_three', engine, chunksize = 10000)
l4 = 0
for i in sql:
    d = i.copy()

    # 注意！！！替换1和替换2的顺序不能颠倒，否则删除不完整
    # 替换1 将类似于http://www.lawtime.cn***/29_1_p3.html下划线后面部分"_1_p3"去掉，规范为标准网址 
    d['fullURL'] = d['fullURL'].str.replace('_\d{0,2}_\w{0,2}.html','.html')#这部分网址有　9260　个
    
    # 替换2 将类似于http://www.lawtime.cn***/2007020619634_2.html下划线后面部分"_2"去掉，规范为标准网址
    d['fullURL'] = d['fullURL'].str.replace('_\d{0,2}.html','.html') #这部分网址有　55455-9260 = 46195 个
    
    d = d.drop_duplicates(['fullURL','userID']) # 删除重复记录(删除有相同网址和相同用户ID的)【不完整】因为不同的数据块中依然有重复数据
    temp = len(d)
    l4 = l4 + temp
    d.to_sql('changed_1', engine, index=False, if_exists = 'append') # 保存

print(l4) # 547608
# Out:
# F:\ProgramData\Anaconda3\envs\normal\lib\site-packages\pymysql\cursors.py:166: Warning: (1366, "Incorrect string value: '\\xD6\\xD0\\xB9\\xFA\\xB1\\xEA...' for column 'VARIABLE_VALUE' at row 481")
#   result = self._query(query)
# F:\ProgramData\Anaconda3\envs\normal\lib\site-packages\pymysql\cursors.py:166: Warning: (1287, "'@@tx_isolation' is deprecated and will be removed in a future release. Please use '@@transaction_isolation' instead")
#   result = self._query(query)
# 547608

# %%
# 【二次筛选】
# 删除重复记录
# 读取数据库数据（基于操作2之后）
engine = create_engine('mysql+pymysql://longfengpili:mysql@123456@127.0.0.1:3306/chapter12?charset=utf8')
sql = pd.read_sql('changed_1', engine, chunksize = 10000)

def dropduplicate(i): 
    j = i[['realIP','fullURL','pageTitle','userID','timestamp_format']].copy()
    return j

counts1 = [dropduplicate(i) for i in sql]
counts1 = pd.concat(counts1)
print(len(counts1))# 547608
a = counts1.drop_duplicates(['fullURL','userID'])
print(len(a))# 528166
savetosql(a, 'changed_2')
# Out:
# F:\ProgramData\Anaconda3\envs\normal\lib\site-packages\pymysql\cursors.py:166: Warning: (1366, "Incorrect string value: '\\xD6\\xD0\\xB9\\xFA\\xB1\\xEA...' for column 'VARIABLE_VALUE' at row 481")
#   result = self._query(query)
# F:\ProgramData\Anaconda3\envs\normal\lib\site-packages\pymysql\cursors.py:166: Warning: (1287, "'@@tx_isolation' is deprecated and will be removed in a future release. Please use '@@transaction_isolation' instead")
#   result = self._query(query)
# 547608
# 528166

# %%
#-----* 2 *-----网址正确分类:手动分析咨询类别和知识类别的网址


# 读取数据库数据 
engine = create_engine('mysql+pymysql://longfengpili:mysql@123456@127.0.0.1:3306/chapter12?charset=utf8')
sql = pd.read_sql('changed_2', engine, chunksize = 10000)

def countzhishi(i):
    j = i[['fullURL']].copy()
    j['type'] = 'else'
    j['type'][j['fullURL'].str.contains('(info)|(faguizt)')] = 'zhishi'
    j['type'][j['fullURL'].str.contains('(ask)|(askzt)')] = 'zixun'
    
    return j
counts2 = [countzhishi(i) for i in sql]
counts2 = pd.concat(counts2)
counts2['type'].value_counts()
# Out:
# F:\ProgramData\Anaconda3\envs\normal\lib\site-packages\pymysql\cursors.py:166: Warning: (1366, "Incorrect string value: '\\xD6\\xD0\\xB9\\xFA\\xB1\\xEA...' for column 'VARIABLE_VALUE' at row 481")
#   result = self._query(query)
# F:\ProgramData\Anaconda3\envs\normal\lib\site-packages\pymysql\cursors.py:166: Warning: (1287, "'@@tx_isolation' is deprecated and will be removed in a future release. Please use '@@transaction_isolation' instead")
#   result = self._query(query)
# F:\ProgramData\Anaconda3\envs\normal\lib\site-packages\ipykernel_launcher.py:11: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   # This is added back by InteractiveShellApp.init_path()
# F:\ProgramData\Anaconda3\envs\normal\lib\site-packages\ipykernel_launcher.py:12: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   if sys.path[0] == '':
# zixun     393185
# zhishi    122197
# else       12784
# Name: type, dtype: int64

# %%
# 统计各个类别占比
a = counts2['type'].value_counts()
b = DataFrame(a)
b.columns = ['num']
b.index.name = 'type'
b['per'] = b['num']/b['num'].sum()
b
# Out:
#            num       per
# type
# zixun   393185  0.744435
# zhishi  122197  0.231361
# else     12784  0.024205

# %%
b[['per']].applymap(lambda x:'{:.2%}'.format(x))
# Out:
#            per
# type
# zixun   74.44%
# zhishi  23.14%
# else     2.42%

# %%
# 第一步 *: 手动分析知识类别的网址，得出知识类别下的二级类别有哪些
c = counts2[counts2['type']=='zhishi']

d = c[c['fullURL'].str.contains('info')]
print(len(d)) # 102140
d['iszsk'] = 'else' # 结果显示是空  
d['iszsk'][d['fullURL'].str.contains('info')] = 'infoelsezsk' # 102032
d['iszsk'][d['fullURL'].str.contains('zhishiku')] = 'zsk' # 108
d['iszsk'].value_counts()  
# 由结果可知，除了‘info'和’zhishifku'没有其他类型，且 【info类型（不包含zhishiku)：infoelsezsk】和【包含zhishiku：zsk】类型无相交的部分。
# 因此分析知识类别下的二级类型时，需要分两部分考虑，求每部分的类别，再求并集，即为所有二级类型
# Out:
# 102140
# F:\ProgramData\Anaconda3\envs\normal\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# F:\ProgramData\Anaconda3\envs\normal\lib\site-packages\pandas\core\generic.py:5233: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# F:\ProgramData\Anaconda3\envs\normal\lib\site-packages\IPython\core\interactiveshell.py:2961: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
# infoelsezsk    102032
# zsk               108
# Name: iszsk, dtype: int64

# %%
d.head()
# Out:
#                                               fullURL    type        iszsk
# 0   http://www.lawtime.cn/info/hunyin/hunyinfagui/...  zhishi  infoelsezsk
# 5   http://www.lawtime.cn/info/laodong/zhiyebing/2...  zhishi  infoelsezsk
# 8   http://www.lawtime.cn/info/hunyin/lhlawlhxy/20...  zhishi  infoelsezsk
# 9   http://www.lawtime.cn/info/zhaiquan/zhaiquangu...  zhishi  infoelsezsk
# 23  http://www.lawtime.cn/info/jiaotong/jtaqchangs...  zhishi  infoelsezsk

# %%
# 第二步 *用正则表达式匹配出网址中二级类别
# 方法：用上面已经处理的'iszsk'列分成两种类别的网址，分别使用正则表达式进行匹配


# 对于http://www.lawtime.cn/info/jiaotong/jtsgcl/2011070996791.html类型的网址进行这样匹配,获取二级类别名称"jiaotong"
import re
e = d[d['iszsk'] == 'infoelsezsk']
def find_2(df):
#     print(df)
    i = df['fullURL']
#     print(i)
    j = re.findall('/info/(.*?)/',i,re.S)
    return j[0]
e['type2'] = e.apply(lambda x:find_2(x),axis=1)
print(e.head())

# 对于http://www.lawtime.cn/zhishiku/laodong/info/***.html类型的网址进行这样匹配,获取二级类别名称"laodong"
# 由于还有一类是http://www.lawtime.cn/zhishiku/laodong/***.html，所以使用'zhishiku/(.*?)/'进行匹配
f = d[d['iszsk'] == 'zsk']
def find_2_2(df):
#     print(df)
    i = df['fullURL']
#     print(i)
    j = re.findall('zhishiku/(.*?)/',i,re.S)
    return j[0]
f['type2'] = f.apply(lambda x:find_2_2(x),axis=1)
print(f.head())

e = e[['fullURL','type','type2']]
f = f[['fullURL','type','type2']]
# Out:
#                                               fullURL    type        iszsk  \
# 0   http://www.lawtime.cn/info/hunyin/hunyinfagui/...  zhishi  infoelsezsk
# 5   http://www.lawtime.cn/info/laodong/zhiyebing/2...  zhishi  infoelsezsk
# 8   http://www.lawtime.cn/info/hunyin/lhlawlhxy/20...  zhishi  infoelsezsk
# 9   http://www.lawtime.cn/info/zhaiquan/zhaiquangu...  zhishi  infoelsezsk
# 23  http://www.lawtime.cn/info/jiaotong/jtaqchangs...  zhishi  infoelsezsk
#
#        type2
# 0     hunyin
# 5    laodong
# 8     hunyin
# 9   zhaiquan
# 23  jiaotong
#                                                 fullURL    type iszsk  \
# 3950  http://www.lawtime.cn/zhishiku/laodong/info/21...  zhishi   zsk
# 420   http://www.lawtime.cn/zhishiku/gongsi/info/108...  zhishi   zsk
# 1486  http://www.lawtime.cn/zhishiku/hunyin/info/177...  zhishi   zsk
# 1506  http://www.lawtime.cn/zhishiku/hunyin/info/177...  zhishi   zsk
# 4658  http://www.lawtime.cn/zhishiku/fangdichan/info...  zhishi   zsk
#
#            type2
# 3950     laodong
# 420       gongsi
# 1486      hunyin
# 1506      hunyin
# 4658  fangdichan
# F:\ProgramData\Anaconda3\envs\normal\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# F:\ProgramData\Anaconda3\envs\normal\lib\site-packages\ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# 第三步 *将列名重命名

e.columns = ['fullURL', 'type1', 'type2']

f.columns = ['fullURL', 'type1', 'type2']

# 将两类处理过二级类别的记录合并，求二级类别的交集
g = pd.concat([e,f])
h = g['type2'].value_counts()

# 求两类网址中的二级类别数，由结果可知，两类网址的二级类别的集合的并集满足所需条件
len(e['type2'].value_counts()) # 66
len(f['type2'].value_counts()) # 31
len(g['type2'].value_counts()) # 69

print(h.head())

print(h.index) # 列出知识类别下的所有的二级类别
# Out:
# hunyin     16824
# laodong    13652
# shuifa     10479
# gongsi      9651
# hetong      8378
# Name: type2, dtype: int64
# Index(['hunyin', 'laodong', 'shuifa', 'gongsi', 'hetong', 'fangdichan',
#        'jiaotong', 'xingfa', 'minfa', 'minshi', 'xiaofeizhe',
#        'laodonghetongfa', 'zscq', 'shengchan', 'xingshisusongfa', 'gongcheng',
#        'zhuanli', 'yiliao', 'lvshi', 'lunwen', 'hehuo', 'zhengdi', 'zhaiquan',
#        'jianding', 'sifakaoshi', 'zhixing', 'hetongshencha', 'shangwu',
#        'baoguanshangjian', 'jingjizhongcai', 'piaoju', 'shipin', 'tiaojie',
#        'sunhai', 'zhaobiaotoubiao', 'zhian', 'flws', 'zhongcai', 'xsbhdl',
#        'maoyi', 'zhaoshang', 'chaiqian', 'guojia', 'paimai', 'qubaohoushen',
#        'zhengquan', 'gongzheng', 'knowledge', 'pochan', 'hjf', 'jingzheng',
#        'guojizhongcai', 'funvquanyi', 'zixindiaocha', 'shangzhang',
#        'fanqingxiao', 'wto', 'wuliu', 'yimin', 'weisheng', 'myfg',
#        'xingshizhengjuxiangguan', 'zaishen', 'wlyxz', 'itfin', 'wenshu',
#        'shangbiao', 'zhuanti', 'fanben'],
#       dtype='object')

# %%
# 将知识类别中不包含zhishiku的提取出来保存到数据库
savetosql(g,'class_2nd')
# Out:
# F:\ProgramData\Anaconda3\envs\normal\lib\site-packages\pymysql\cursors.py:166: Warning: (1366, "Incorrect string value: '\\xD6\\xD0\\xB9\\xFA\\xB1\\xEA...' for column 'VARIABLE_VALUE' at row 481")
#   result = self._query(query)
# F:\ProgramData\Anaconda3\envs\normal\lib\site-packages\pymysql\cursors.py:166: Warning: (1287, "'@@tx_isolation' is deprecated and will be removed in a future release. Please use '@@transaction_isolation' instead")
#   result = self._query(query)

# %%
e.head()
# Out:
#                                               fullURL   type1     type2
# 0   http://www.lawtime.cn/info/hunyin/hunyinfagui/...  zhishi    hunyin
# 5   http://www.lawtime.cn/info/laodong/zhiyebing/2...  zhishi   laodong
# 8   http://www.lawtime.cn/info/hunyin/lhlawlhxy/20...  zhishi    hunyin
# 9   http://www.lawtime.cn/info/zhaiquan/zhaiquangu...  zhishi  zhaiquan
# 23  http://www.lawtime.cn/info/jiaotong/jtaqchangs...  zhishi  jiaotong

# %%
q = g.copy()
def find_class3(series):
    i = series['fullURL']
    j = series['type2']
    k = np.nan
    try:
        k = re.findall(r'/info/{}/(.*?)/'.format(j),i)[0]
    except:
        pass
#     print(k)

    return k
    
q['type3'] = q.apply(find_class3,axis = 1)
q.head()
# Out:
#                                               fullURL   type1     type2  \
# 0   http://www.lawtime.cn/info/hunyin/hunyinfagui/...  zhishi    hunyin
# 5   http://www.lawtime.cn/info/laodong/zhiyebing/2...  zhishi   laodong
# 8   http://www.lawtime.cn/info/hunyin/lhlawlhxy/20...  zhishi    hunyin
# 9   http://www.lawtime.cn/info/zhaiquan/zhaiquangu...  zhishi  zhaiquan
# 23  http://www.lawtime.cn/info/jiaotong/jtaqchangs...  zhishi  jiaotong
#
#              type3
# 0      hunyinfagui
# 5        zhiyebing
# 8        lhlawlhxy
# 9   zhaiquanguanli
# 23    jtaqchangshi

# %%
savetosql(q,'class_3nd')
# Out:
# F:\ProgramData\Anaconda3\envs\normal\lib\site-packages\pymysql\cursors.py:166: Warning: (1366, "Incorrect string value: '\\xD6\\xD0\\xB9\\xFA\\xB1\\xEA...' for column 'VARIABLE_VALUE' at row 481")
#   result = self._query(query)
# F:\ProgramData\Anaconda3\envs\normal\lib\site-packages\pymysql\cursors.py:166: Warning: (1287, "'@@tx_isolation' is deprecated and will be removed in a future release. Please use '@@transaction_isolation' instead")
#   result = self._query(query)

# %%
# 统计婚姻类下面的三级类别的数目
r = q[q.type2 == 'hunyin']['type3'].value_counts()
print(len(r))
r[:5]
# Out:
# 145
# lhlawlhxy       4674
# hunyinfagui     1528
# jihuashengyu     926
# jiehun           695
# ccfglhccfg       572
# Name: type3, dtype: int64

# %%
# 第六步 *目标：将类别3按照每类降序排列，然后保存
s = q.groupby(['type2','type3'])[['type1']].count()
r = s.reset_index().sort_values(by = ['type2','type1'],ascending=[True,False])
r.set_index(['type2','type3'],inplace=True)
r[:10]
# Out:
#                                           type1
# type2            type3
# baoguanshangjian baoguandanzheng             77
#                  dongtai                     38
#                  baoguanshangjianfalv        34
#                  guanshui                    23
#                  chukoubaoguan               22
#                  jinkoubaoguanliucheng       13
#                  chukoushangjianliucheng     11
#                  haiguanbaoguan              11
#                  jinkoubaoguan               11
#                  baoguanfei                  10

# %%
#-----* 3 *-----获取后续建模需要的数据  咨询（ask）和婚姻（hunyin）数据
m = counts2[counts2['type'] == 'zixun']
n =counts2[counts2['fullURL'].str.contains('hunyin')]
p = m[m['fullURL'].str.contains('hunyin')]
p # 结果为空，可知，包含zixun的页面中不包含hunyin，两者没有交集
savetosql(m,'zixun')
savetosql(n,'hunyin')
# Out:
# F:\ProgramData\Anaconda3\envs\normal\lib\site-packages\pymysql\cursors.py:166: Warning: (1366, "Incorrect string value: '\\xD6\\xD0\\xB9\\xFA\\xB1\\xEA...' for column 'VARIABLE_VALUE' at row 481")
#   result = self._query(query)
# F:\ProgramData\Anaconda3\envs\normal\lib\site-packages\pymysql\cursors.py:166: Warning: (1287, "'@@tx_isolation' is deprecated and will be removed in a future release. Please use '@@transaction_isolation' instead")
#   result = self._query(query)

# %%
#  获取后续建模需要的数据  咨询（ask）和婚姻（hunyin）数据
# 读取数据库数据 
engine = create_engine('mysql+pymysql://longfengpili:mysql@123456@127.0.0.1:3306/chapter12?charset=utf8')
sql = pd.read_sql('all_gzdata', engine, chunksize = 10000)
l1 = 0
l2 = 0
for i in sql:
    zixun = i[['realIP','fullURL']][i['fullURL'].str.contains('(ask)|(askzt)')].copy()
#     l1 = len(zixun) + l1
    hunyin = i[['realIP','fullURL']][i['fullURL'].str.contains('hunyin')].copy()    
#     l2 = len(hunyin) + l2
    zixun.to_sql('zixunformodel', engine, index=False,if_exists = 'append')
    hunyin.to_sql('hunyinformodel', engine, index=False,if_exists = 'append')
# print l1,l2
# Out:
# F:\ProgramData\Anaconda3\envs\normal\lib\site-packages\pymysql\cursors.py:166: Warning: (1366, "Incorrect string value: '\\xD6\\xD0\\xB9\\xFA\\xB1\\xEA...' for column 'VARIABLE_VALUE' at row 481")
#   result = self._query(query)
# F:\ProgramData\Anaconda3\envs\normal\lib\site-packages\pymysql\cursors.py:166: Warning: (1287, "'@@tx_isolation' is deprecated and will be removed in a future release. Please use '@@transaction_isolation' instead")
#   result = self._query(query)
# F:\ProgramData\Anaconda3\envs\normal\lib\site-packages\ipykernel_launcher.py:8: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
